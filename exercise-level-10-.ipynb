# %% [markdown]
# # EXERCISE MODULE_10

# %% [markdown]
# EXERCISE LEVEL ONE

# %% [markdown]
# 1.Python has the module called statistics and we can use this module to do all the statistical calculations. However, to learn how to make function and reuse function let us try to develop a program, which calculates the measure of central tendency of a sample (mean, median, mode) and measure of variability (range, variance, standard deviation). In addition to those measures, find the min, max, count, percentile, and frequency distribution of the sample. You can create a class called Statistics and create all the functions that do statistical calculations as methods for the Statistics class. Check the output below.

# %%
ages = [31, 26, 34, 37, 27, 26, 32, 32, 26, 27, 27, 24, 32, 33, 27, 25, 26, 38, 37, 31, 34, 24, 33, 29, 26]
data = Statistics(ages)

class Statistics:
    def __init__(self, data):
        self.data = data

    def count(self):
        return len(self.data)
 
    def sum(self):
        return sum(self.data)

    def min(self):
        return min(self.data)

    def max(self):
        return max(self.data)

    def range(self):
        return self.max() - self.min()

    def mean(self):
        return self.sum() / self.count()
 
    def median(self):
        sorted_data = sorted(self.data)
        n = self.count()
        mid = n // 2
        if n % 2 == 0:
            return (sorted_data[mid - 1] + sorted_data[mid]) / 2
        else:
            return sorted_data[mid]

    def mode(self):
        from collections import Counter
        freq = Counter(self.data)
        max_count = max(freq.values())
        mode = [key for key, val in freq.items() if val == max_count]
        return {"mode": mode, "count": max_count}

    def std(self):
        return self.var() ** 0.5

    def var(self):
        mean = self.mean()
        return sum((x - mean) ** 2 for x in self.data) / self.count()

    def freq_dist(self):
        from collections import Counter
        freq = Counter(self.data)
        return sorted(freq.items(), key=lambda x: (-x[1], x[0]))


print('Count:', data.count())
print('Sum: ', data.sum())
print('Min: ', data.min())
print('Max: ', data.max())
print('Range: ', data.range())
print('Mean: ', data.mean())
print('Median: ', data.median())
print('Mode: ', data.mode())
print('Standard Deviation: ', data.std())
print('Variance: ', data.var())
print('Frequency Distribution: ', data.freq_dist())
# Out:
# Count: 25
# Sum:  744
# Min:  24
# Max:  38
# Range:  14
# Mean:  29.76
# Median:  29
# Mode:  {'mode': [26], 'count': 5}
# Standard Deviation:  4.188364836066696
# Variance:  17.5424
# Frequency Distribution:  [(26, 5), (27, 4), (32, 3), (24, 2), (31, 2), (33, 2), (34, 2), (37, 2), (25, 1), (29, 1), (38, 1)]

# %% [markdown]
# ## Exercises: Level 2

# %% [markdown]
# 1.Create a class called PersonAccount. It has firstname, lastname, incomes, expenses properties and it has total_income, total_expense, account_info, add_income, add_expense and account_balance methods. Incomes is a set of incomes and its description. The same goes for expenses.

# %%
class personaccount:

    def __init__ (self,firstname,lastname,icomes,expenses_properties,Total_income,Total_expenses,account_info,add_income,add_expenses,account_balance):
        self.firstname = abdulmalik
        self.lastname = bashir
        self.incomes = 10000
        self.expenses_properties = 3000
        self.Total_income =7000
        self.Total_expenses = 3000
        self.account_info = savingaccount
        self.add_income = freelencework
        self.add_expense = monthlysubscription
        self.account_balance = 7000

    def account_info(self):
        return  f'{self.firstname} {self.lastname} account_balance is {self.account_balance}'
        p = person('abdulmalik','bashir','7000')
